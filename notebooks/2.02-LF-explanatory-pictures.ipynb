# %%
import os
import re
import sys
import warnings

import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from IPython.display import display
from typing import Iterator, List, Dict

warnings.filterwarnings("ignore")

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
plt.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')


PROJ_ROOT = Path.cwd().parent

print(f"Project root: {PROJ_ROOT}")

if str(PROJ_ROOT) not in sys.path:
    sys.path.append(str(PROJ_ROOT))

from collusion_judges.dataset.make_graph import build_judge_graph

# %load_ext autoreload
# %autoreload 2
# Out:
# Project root: /home/frantsuaza/Documents/Science/SportLab/collusion_judges
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---
# # **I. Make Graphs**

# %%
G, edges_df, nodes_df, pair_corrs_df = build_judge_graph(
    None,
    score_col="judge_component_score_norm",
    min_common=3,
)

# %%
nodes_df
# Out:
#               judge_name judge_country  degree  n_common_acts  pearson_mean  \
# 0          Lorrie PARKER           USA      28              8      0.855822
# 1       Susanne SJÖQUIST           SWE      13              4      0.917273
# 2             Steven HSU           USA       8              2      0.907321
# 3      Christian BAUMANN           DEU       8              2      0.910838
# 4           Etsuko AZUMA           JPN      21              6      0.837766
# ..                   ...           ...     ...            ...           ...
# 212       Lorna SCHRODER           CAN       8              2      0.864661
# 213  Luise Tarja BOEHLKE           DEU       8              2      0.899059
# 214        Jennifer MAST           USA       8              2      0.932989
# 215     Nicholas RUSSELL           GBR       8              2      0.877114
# 216          David MUNOZ           ESP       8              2      0.957794
#
#      pearson_median  pearson_min  pearson_max  pearson_std  spearman_mean  \
# 0          0.881218     0.482372     0.989529     0.092334       0.825138
# 1          0.933553     0.771005     0.967492     0.044486       0.856782
# 2          0.911028     0.843835     0.973209     0.037763       0.601131
# 3          0.913744     0.838402     0.963498     0.032664       0.805778
# 4          0.851931     0.612426     0.965906     0.082934       0.826316
# ..              ...          ...          ...          ...            ...
# 212        0.875858     0.679599     0.973177     0.083567       0.823141
# 213        0.915275     0.724308     0.972102     0.066694       0.868620
# 214        0.938916     0.821925     0.978817     0.038873       0.913458
# 215        0.865691     0.776937     0.968055     0.064126       0.842695
# 216        0.954870     0.934671     0.978911     0.015783       0.803379
#
#      spearman_median  spearman_min  spearman_max  spearman_std  kendall_mean  \
# 0           0.846737      0.254550      1.000000      0.131333      0.703795
# 1           0.867945      0.656627      0.997725      0.098616      0.758140
# 2           0.590966      0.383240      0.884865      0.156263      0.489700
# 3           0.761750      0.678928      0.939042      0.101173      0.688452
# 4           0.838899      0.476358      0.965834      0.103904      0.689907
# ..               ...           ...           ...           ...           ...
# 212         0.853263      0.557083      0.981818      0.113973      0.697834
# 213         0.883796      0.656375      0.978728      0.090414      0.753411
# 214         0.929778      0.695122      0.984807      0.064961      0.808049
# 215         0.843217      0.743123      0.966258      0.069748      0.720010
# 216         0.809451      0.723408      0.913650      0.057131      0.677479
#
#      kendall_median  kendall_min  kendall_max  kendall_std
# 0          0.714286     0.113228     1.000000     0.150265
# 1          0.763266     0.518519     0.990867     0.117607
# 2          0.464286     0.296296     0.792594     0.157128
# 3          0.636849     0.552052     0.841126     0.113081
# 4          0.682199     0.351155     0.904762     0.127518
# ..              ...          ...          ...          ...
# 212        0.715626     0.425999     0.927273     0.144081
# 213        0.758671     0.571591     0.943880     0.115738
# 214        0.811497     0.568182     0.943880     0.087691
# 215        0.712539     0.584307     0.906977     0.096745
# 216        0.666846     0.584307     0.800499     0.070621
#
# [217 rows x 19 columns]

# %% [markdown]
# ---
# # **II. Make plots**
